# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.0.1/spark-3.0.1-bin-hadoop2.7.tgz
# !tar xf spark-3.0.1-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.1-bin-hadoop2.7"
import findspark
findspark.init()
findspark.find()
from pyspark.sql import SparkSession
from pyspark.sql.functions import array_contains

# %% [markdown]
# ### Connect to MongoDB

# %%
USERNAME = PASSWORD = 'sri'
CNCT_STR = f'mongodb+srv://{USERNAME}:{PASSWORD}@svp-cluster.1uzpyjf.mongodb.net/svp_database.video_tags_json?retryWrites=true'
FORMAT = 'com.mongodb.spark.sql.DefaultSource'

# %%
spark = SparkSession \
        .builder \
        .appName('spark_video_processing') \
        .master('local')\
        .config('spark.mongodb.input.uri', CNCT_STR) \
        .config('spark.mongodb.output.uri', CNCT_STR) \
        .config('spark.jars.packages', 'org.mongodb.spark:mongo-spark-connector_2.12:3.0.1') \
        .getOrCreate()

# %% [markdown]
# ### Read from MongoDB

# %%
video_tags = spark.read \
             .format(FORMAT) \
             .option('uri', CNCT_STR) \
             .load()

# %%
video_tags.printSchema()
# Out:
# root
#  |-- _id: struct (nullable = true)
#  |    |-- oid: string (nullable = true)
#  |-- tags: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- video_id: string (nullable = true)
#  |-- video_path: string (nullable = true)

# %%
video_tags.show()
# Out:
# +--------------------+--------------------+-----------+--------------------+
# |                 _id|                tags|   video_id|          video_path|
# +--------------------+--------------------+-----------+--------------------+
# |[638824df291310e6...|[filing cabinet, ...|9dWxCvcK6H4|data/v/9dWxCvcK6H...|
# |[638824df291310e6...|[baby bib, oxygen...|a1zf0TQcdFQ|data/v/a1zf0TQcdF...|
# |[638824df291310e6...|[combine harveste...|dnzvSdAF9Ns|data/v/dnzvSdAF9N...|
# |[638824df291310e6...|[barometer, spira...|gCQ42PwhZCc|data/v/gCQ42PwhZC...|
# |[638824df291310e6...|[European green l...|nDGcDKA30W0|data/v/nDGcDKA30W...|
# |[638824df291310e6...|[killer whale, ca...|sHn8LBYNm_o|data/v/sHn8LBYNm_...|
# |[638824df291310e6...|[television, watc...|sxBGkWEywxU|data/v/sxBGkWEywx...|
# |[638824df291310e6...|[punching bag, ca...|-aQWllQVgac|data/v/-aQWllQVga...|
# |[638824df291310e6...|[cardboard box / ...|8RWwmPCSoqc|data/v/8RWwmPCSoq...|
# |[638824df291310e6...|[mobile home, pon...|96DHjKlLJUQ|data/v/96DHjKlLJU...|
# |[638824df291310e6...|[axolotl, white s...|Bvp2IwwoHvY|data/v/Bvp2IwwoHv...|
# |[638824df291310e6...|[hair spray, loti...|C_A4OLnGEbk|data/v/C_A4OLnGEb...|
# |[638824df291310e6...|[soccer ball, swi...|IF1D28mjfqQ|data/v/IF1D28mjfq...|
# |[638824df291310e6...|[barometer, spira...|LwmdKItl57w|data/v/LwmdKItl57...|
# |[638824df291310e6...|[hair spray, remo...|RUFujW3Uwmo|data/v/RUFujW3Uwm...|
# |[638824df291310e6...|[face powder, hai...|X-Jlh2ntOuY|data/v/X-Jlh2ntOu...|
# |[638824df291310e6...|[cardboard box / ...|eAbwz9lRqGQ|data/v/eAbwz9lRqG...|
# |[638824df291310e6...|[barometer, barre...|eOuH_ShwyaA|data/v/eOuH_Shwya...|
# |[638824df291310e6...|[car mirror, meas...|ffrLyIKGAjE|data/v/ffrLyIKGAj...|
# |[638824df291310e6...|[hair spray, loti...|i3U_-RgNwNk|data/v/i3U_-RgNwN...|
# +--------------------+--------------------+-----------+--------------------+
# only showing top 20 rows

# %%
QUERY_TAG = 'soccer ball'
df = video_tags.filter(array_contains(video_tags.tags, QUERY_TAG)).toPandas()
df
# Out:
#                            _id  \
# 0  (638824df291310e6c7f06b2b,)
# 1  (638824df291310e6c7f06b87,)
# 2  (638824df291310e6c7f06c41,)
# 3  (638824df291310e6c7f06cf9,)
#
#                                                 tags     video_id  \
# 0  [soccer ball, swing, juggling soccer ball, pas...  IF1D28mjfqQ
# 1                 [soccer ball, passing soccer ball]  ID7rAWGNR6Q
# 2  [soccer ball, suit, velvet fabric, chopping me...  xeaQX9lvAMo
# 3  [racket, soccer ball, swing, volleyball, shoot...  upaGn7gC8bo
#
#                video_path
# 0  data/v/IF1D28mjfqQ.mp4
# 1  data/v/ID7rAWGNR6Q.mp4
# 2  data/v/xeaQX9lvAMo.mp4
# 3  data/v/upaGn7gC8bo.mp4

# %%
QUERY_TAG = 'throwing snowballs'
df = video_tags.filter(array_contains(video_tags.tags, QUERY_TAG)).toPandas()
df
# Out:
#                            _id  \
# 0  (638824df291310e6c7f06b84,)
# 1  (638824df291310e6c7f06bb9,)
# 2  (638824df291310e6c7f06c38,)
#
#                                                 tags     video_id  \
# 0  [bikini, movie theater, front curtain, belly d...  hqs8a5e7kPs
# 1  [car mirror, seat belt, sleeping bag, beatboxi...  sgx9W6VGJjk
# 2  [backpack, candle, cliff, base jumping, diving...  Wd47jL6Hwn4
#
#                video_path
# 0  data/v/hqs8a5e7kPs.mp4
# 1  data/v/sgx9W6VGJjk.mp4
# 2  data/v/Wd47jL6Hwn4.mp4

# %% [markdown]
# #### Conditional queries

# %% [markdown]
# #### Conditional OR

# %%
QUERY_TAG1 = 'car mirror'
QUERY_TAG2 = 'driving car'
df1 = video_tags.filter(array_contains(video_tags.tags, QUERY_TAG1))
df2 = video_tags.filter(array_contains(video_tags.tags, QUERY_TAG2))
df = df1.union(df2).toPandas()
df
# Out:
#                             _id  \
# 0   (638824df291310e6c7f06b24,)
# 1   (638824df291310e6c7f06b31,)
# 2   (638824df291310e6c7f06b67,)
# 3   (638824df291310e6c7f06b80,)
# 4   (638824df291310e6c7f06b93,)
# 5   (638824df291310e6c7f06b95,)
# 6   (638824df291310e6c7f06b9f,)
# 7   (638824df291310e6c7f06bb9,)
# 8   (638824df291310e6c7f06bcf,)
# 9   (638824df291310e6c7f06be0,)
# 10  (638824df291310e6c7f06be3,)
# 11  (638824df291310e6c7f06be5,)
# 12  (638824df291310e6c7f06bf5,)
# 13  (638824df291310e6c7f06c1b,)
# 14  (638824df291310e6c7f06c1e,)
# 15  (638824df291310e6c7f06c2b,)
# 16  (638824df291310e6c7f06c3c,)
# 17  (638824df291310e6c7f06cba,)
# 18  (638824df291310e6c7f06cd2,)
# 19  (638824df291310e6c7f06cd6,)
# 20  (638824df291310e6c7f06ce0,)
# 21  (638824df291310e6c7f06ceb,)
# 22  (638824df291310e6c7f06d16,)
# 23  (638824df291310e6c7f06b24,)
# 24  (638824df291310e6c7f06bcc,)
# 25  (638824df291310e6c7f06bf5,)
# 26  (638824df291310e6c7f06c2b,)
# 27  (638824df291310e6c7f06c64,)
# 28  (638824df291310e6c7f06cba,)
# 29  (638824df291310e6c7f06d0e,)
#
#                                                  tags     video_id  \
# 0   [killer whale, car mirror, hook, pajamas, soap...  sHn8LBYNm_o
# 1   [car mirror, measuring cup, guacamole, cabbage...  ffrLyIKGAjE
# 2   [high-speed train, car mirror, microwave oven,...  -8zyilOZHLU
# 3   [car mirror, car wheel, hair spray, jeep, prin...  Qtu7C8_kl5I
# 4   [car mirror, eating burger, hoverboarding, put...  I4K2G76pdpo
# 5   [killer whale, car mirror, paddle, motorboat, ...  n1KCf9ijDD4
# 6   [car mirror, cliff, blasting sand, diving clif...  clofw7v0tfo
# 7   [car mirror, seat belt, sleeping bag, beatboxi...  sgx9W6VGJjk
# 8   [car mirror, tray, consomme, exercising arm, p...  jK0lPR3Djjo
# 9   [electric ray, flatworm, chiton, car mirror, a...  yjfEJVXn9A0
# 10  [bulletproof vest, car mirror, police van, new...  _f3R6h8qSz8
# 11  [car mirror, hair dryer, loupe magnifying glas...  3NOy3a3B0OU
# 12  [car mirror, changing gear in car, driving car...  QamPzj0Xzek
# 13  [car mirror, envelope, face powder, hair clip,...  Vh80Oz0xP7w
# 14  [pelican, baseball, car mirror, bubble, barten...  bz8GBSge8WE
# 15  [car mirror, minivan, necklace, changing gear ...  SCpXjVRQ3sI
# 16           [car mirror, cleaning gutters, unboxing]  omYVOpFXFbk
# 17  [car mirror, breathing fire, driving car, news...  1kvdhlA_BXY
# 18  [car mirror, seat belt, changing gear in car, ...  fBwYfrhkwQg
# 19  [car mirror, drumstick, T-shirt, plectrum, blo...  6w1SlO4UeC0
# 20  [wheelbarrow, car mirror, seat belt, changing ...  HJmGGrhkihU
# 21  [station wagon, car mirror, car wheel, bartend...  yC9609uFhhQ
# 22  [car mirror, calligraphy, folding paper, rippi...  hBcgz5SYgpI
# 23  [killer whale, car mirror, hook, pajamas, soap...  sHn8LBYNm_o
# 24              [odometer, driving car, steering car]  NAy39k0o6aI
# 25  [car mirror, changing gear in car, driving car...  QamPzj0Xzek
# 26  [car mirror, minivan, necklace, changing gear ...  SCpXjVRQ3sI
# 27  [flagpole, mosque, blasting sand, directing tr...  lrJKUSo4t9Q
# 28  [car mirror, breathing fire, driving car, news...  1kvdhlA_BXY
# 29  [tow truck, semi-trailer truck, driving car, f...  tcfbTV5suwQ
#
#                 video_path
# 0   data/v/sHn8LBYNm_o.mp4
# 1   data/v/ffrLyIKGAjE.mp4
# 2   data/v/-8zyilOZHLU.mp4
# 3   data/v/Qtu7C8_kl5I.mp4
# 4   data/v/I4K2G76pdpo.mp4
# 5   data/v/n1KCf9ijDD4.mp4
# 6   data/v/clofw7v0tfo.mp4
# 7   data/v/sgx9W6VGJjk.mp4
# 8   data/v/jK0lPR3Djjo.mp4
# 9   data/v/yjfEJVXn9A0.mp4
# 10  data/v/_f3R6h8qSz8.mp4
# 11  data/v/3NOy3a3B0OU.mp4
# 12  data/v/QamPzj0Xzek.mp4
# 13  data/v/Vh80Oz0xP7w.mp4
# 14  data/v/bz8GBSge8WE.mp4
# 15  data/v/SCpXjVRQ3sI.mp4
# 16  data/v/omYVOpFXFbk.mp4
# 17  data/v/1kvdhlA_BXY.mp4
# 18  data/v/fBwYfrhkwQg.mp4
# 19  data/v/6w1SlO4UeC0.mp4
# 20  data/v/HJmGGrhkihU.mp4
# 21  data/v/yC9609uFhhQ.mp4
# 22  data/v/hBcgz5SYgpI.mp4
# 23  data/v/sHn8LBYNm_o.mp4
# 24  data/v/NAy39k0o6aI.mp4
# 25  data/v/QamPzj0Xzek.mp4
# 26  data/v/SCpXjVRQ3sI.mp4
# 27  data/v/lrJKUSo4t9Q.mp4
# 28  data/v/1kvdhlA_BXY.mp4
# 29  data/v/tcfbTV5suwQ.mp4

# %% [markdown]
# #### Conditional AND

# %%
QUERY_TAG1 = 'car mirror'
QUERY_TAG2 = 'driving car'
df1 = video_tags.filter(array_contains(video_tags.tags, QUERY_TAG1))
df2 = video_tags.filter(array_contains(video_tags.tags, QUERY_TAG2))
df = df1.intersect(df2).toPandas()
print([f'https://www.youtube.com/watch?v={v_id}' for v_id in df['video_id'].tolist()])
df
# Out:
# ['https://www.youtube.com/watch?v=1kvdhlA_BXY', 'https://www.youtube.com/watch?v=sHn8LBYNm_o', 'https://www.youtube.com/watch?v=QamPzj0Xzek', 'https://www.youtube.com/watch?v=SCpXjVRQ3sI']
#                            _id  \
# 0  (638824df291310e6c7f06cba,)
# 1  (638824df291310e6c7f06b24,)
# 2  (638824df291310e6c7f06bf5,)
# 3  (638824df291310e6c7f06c2b,)
#
#                                                 tags     video_id  \
# 0  [car mirror, breathing fire, driving car, news...  1kvdhlA_BXY
# 1  [killer whale, car mirror, hook, pajamas, soap...  sHn8LBYNm_o
# 2  [car mirror, changing gear in car, driving car...  QamPzj0Xzek
# 3  [car mirror, minivan, necklace, changing gear ...  SCpXjVRQ3sI
#
#                video_path
# 0  data/v/1kvdhlA_BXY.mp4
# 1  data/v/sHn8LBYNm_o.mp4
# 2  data/v/QamPzj0Xzek.mp4
# 3  data/v/SCpXjVRQ3sI.mp4

# %% [markdown]
# car mirror,breathing fire,driving car,news anchoring,smoking,smoking pipe; 1kvdhlA_BXY
#
# car mirror,changing gear in car,driving car,pushing car,vacuuming car; QamPzj0Xzek
